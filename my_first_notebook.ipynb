# %% [markdown]
# Hardware
# Definition: Physical components of a computer that you can see and touch.
# Examples: Keyboard, mouse, monitor, CPU, hard disk.
# Software
# Definition: Programs or instructions that tell the hardware what to do. You cannot touch software.
# Examples: Operating systems, apps, games, browsers.
